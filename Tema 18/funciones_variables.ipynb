# %%
def Q(Q):
    return Q
def L(L):
    return L
def L_1(L_1):
    return L_1
def L_2(L_2):
    return L_2
def L_3(L_3):
    return L_3
def L_4(L_4):
    return L_4
def L_5(L_5):
    return L_5
def D(D):
    return D
def D_1(D_1):
    return D_1
def D_2(D_2):
    return D_2
def D_3(D_3):
    return D_3
def D_4(D_4):
    return D_4
def D_5(D_5):
    return D_5
def D_6(D_6):
    return D_6
def D_boquilla(D_boquilla):
    return D_boquilla
def s(s):
    return s
def rugosidad(rugosidad):
    return rugosidad
def z_A(z_A):
    return z_A
def z_a(z_a):
    return z_a
def z_b(z_b):
    return z_b
def z_c(z_c):
    return z_c
def z_n(z_n):
    return z_n
def z_3(z_3):
    return z_3
def z_4(z_4):
    return z_4
def z_5(z_5):
    return z_5
def z_6(z_6):
    return z_6
def P_A(P_A):
    return P_A
def P_B(P_B):
    return P_B
def P_C(P_C):
    return P_C
def p_4(p_4):
    return p_4
def p_3(p_3):
    return p_3
def v_a(v_a):
    return v_a
def v_b(v_b):
    return v_b
def K_v(K_v):
    return K_v
def B_N2(B_N2):
    return B_N2
def Pot_bruta(Pot_bruta):
    return Pot_bruta
def Eficiencia(Eficiencia):
    return Eficiencia
def K_codo(K_codo):
    return K_codo
def K_valvula(K_valvula):
    return K_valvula
def K_boquilla(K_boquilla):
    return K_boquilla
