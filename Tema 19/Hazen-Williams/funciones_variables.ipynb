# %%
def L(L):
    return L
def L_1(L_1):
    return L_1
def L_2(L_2):
    return L_2
def L_3(L_3):
    return L_3
def L_4(L_4):
    return L_4
def L_5(L_5):
    return L_5
def L_AB(L_AB):
    return L_AB
def L_BC(L_BC):
    return L_BC
def D(D):
    return D
def D_1(D_1):
    return D_1
def D_2(D_2):
    return D_2
def D_3(D_3):
    return D_3
def D_4(D_4):
    return D_4
def D_5(D_5):
    return D_5
def D_AB(D_AB):
    return D_AB
def D_boquilla(D_boquilla):
    return D_boquilla
def Q(Q):
    return Q
def Q_5(Q_5):
    return Q_5
def P_bruta(P_bruta):
    return P_bruta
def rendimiento(rendimiento):
    return rendimiento
def rugosidad(rugosidad):
    return rugosidad
def rugosidad_1(rugosidad_1):
    return rugosidad_1
def rugosidad_2(rugosidad_2):
    return rugosidad_2
def rugosidad(rugosidad):
    return rugosidad
def P_A(P_A):
    return P_A
def P_B(P_B):
    return P_B
def P_C(P_C):
    return P_C
def P_D(P_D):
    return P_D
def z_a(z_a):
    return z_a
def z_b(z_b):
    return z_b
def z_c(z_c):
    return z_c
def z_d(z_d):
    return z_d
def v_a(v_a):
    return v_a
def v_b(v_b):
    return v_b
def v_c(v_c):
    return v_c
def v_d(v_d):
    return v_d
def K_junta(K_junta):
    return K_junta
def K_entrada(K_entrada):
    return K_entrada
def K_salida(K_salida):
    return K_salida
