# %%
def D(D):
    return D
def D_1(D_1):
    return D_1
def D_2(D_2):
    return D_2
def D_3(D_3):
    return D_3
def d_boquilla(d_boquilla):
    return d_boquilla
def L(L):
    return L
def L_1(L_1):
    return L_1
def L_2(L_2):
    return L_2
def L_3(L_3):
    return L_3
def L_4(L_4):
    return L_4
def L_1_eq(L_1_eq):
    return L_1_eq
def L_2_eq(L_2_eq):
    return L_2_eq
def L_3_eq(L_3_eq):
    return L_3_eq
def L_4_eq(L_4_eq):
    return L_4_eq
def z_a(z_a):
    return z_a
def z_b(z_b):
    return z_b
def P_A(P_A):
    return P_A
def P_B(P_B):
    return P_B
def P_A_mbar(P_A_mbar):
    return P_A_mbar
def s(s):
    return s
def v_a(v_a):
    return v_a
def v_boquilla(v_boquilla):
    return v_boquilla
def K_borda(K_borda):
    return K_borda
def K_valvula_compuerta(K_valvula_compuerta):
    return K_valvula_compuerta
def K_valvula_esferica(K_valvula_esferica):
    return K_valvula_esferica
def K_codos_radio_medio(K_codos_radio_medio):
    return K_codos_radio_medio
def rugosidad(rugosidad):
    return rugosidad
def k_boq(k_boq):
    return k_boq
def Q_a(Q_a):
    return Q_a
def H(H):
    return H
def rugosidad_1(rugosidad_1):
    return rugosidad_1
def rugosidad_2(rugosidad_2):
    return rugosidad_2
def rugosidad_4(rugosidad_4):
    return rugosidad_4
